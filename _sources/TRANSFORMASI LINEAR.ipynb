# %% [markdown]
# # TRANSFORMASI LINIER

# %% [markdown]
# ## DEFINISI TRANSFORMASI LINER
# Transformasi linier adalah fungsi atau pemetaan dari satu ruang vektor ke ruang vektor lain (bisa ruang yang sama atau berbeda) yang mempertahankan operasi penjumlahan vektor dan perkalian skalar.
#
# Secara Formal:
#
# Jika $T: \mathbb{R}^n \rightarrow \mathbb{R}^m$ adalah transformasi linier, maka untuk semua vektor $\mathbf{u}, \mathbf{v} \in \mathbb{R}^n$ dan skalar $c \in \mathbb{R}$, berlaku:
#
#
#
#
# \begin{align}
#     T(\mathbf{u} + \mathbf{v}) &= T(\mathbf{u}) + T(\mathbf{v}) \\
#     T(c\mathbf{u}) &= c \cdot T(\mathbf{u})
# \end{align}
#
#
#
# ### Contoh Transformasi Linier
#
# * Rotasi (memutar vektor)
# * Refleksi (pencerminan terhadap sumbu tertentu)
# * Penskalaan (perbesar/perkecil ukuran vektor)
# * Shear (geser bentuk)

# %% [markdown]
# ## DEFINISI TRANSFORMASI BIDANG MIRING (Shear)
# Transformasi bidang miring adalah transformasi linier yang menggeser satu koordinat suatu vektor proporsional terhadap koordinat lainnya, tanpa mengubah volume (determinannya tetap 1 jika shear murni).
#
# ### Transformasi Rotasi Pada Bidang Miring
# adalah gabungan konsep rotasi dan bidang miring (shear),
# Dalam matematika, rotasi adalah transformasi yang memutar vektor terhadap titik asal, sedangkan bidang miring biasanya mengacu pada perubahan bentuk melalui shear.

# %% [markdown]
# ### Memebuktikan Transformasi Rotasi Bidang
#
# Kita ingin membuktikan bahwa transformasi linier $T: \mathbb{R}^2 \to \mathbb{R}^2$ yang merepresentasikan rotasi berlawanan arah jarum jam sebesar sudut $\theta$, bisa dinyatakan dengan matriks:
#
# $$
# A =
# \begin{bmatrix}
# \cos \theta & -\sin \theta \\
# \sin \theta & \cos \theta
# \end{bmatrix}
# $$
#
# ## Langkah-langkah
#
# 1. Misalkan kita punya vektor $\mathbf{v} = (x, y)$. Kita bisa ubah ke bentuk koordinat polar:
#
# $$
# \mathbf{v} = (x, y) = (r \cos \alpha, r \sin \alpha)
# $$
#
# Di mana:
# - $r$ adalah panjang dari vektor $\mathbf{v}$
# - $\alpha$ adalah sudut antara vektor $\mathbf{v}$ dan sumbu-x positif
#
# 2. Jika vektor tersebut diputar sebesar $\theta$, maka posisinya menjadi:
#
# $$
# \mathbf{v'} = (r \cos(\alpha + \theta),\ r \sin(\alpha + \theta))
# $$
#
# 3. Gunakan identitas trigonometri sudut jumlah:
#
# $$
# \cos(\alpha + \theta) = \cos \alpha \cos \theta - \sin \alpha \sin \theta
# $$
# $$
# \sin(\alpha + \theta) = \sin \alpha \cos \theta + \cos \alpha \sin \theta
# $$
#
# Maka:
#
# $$
# \mathbf{v'} = r
# \begin{bmatrix}
# \cos \alpha \cos \theta - \sin \alpha \sin \theta \\
# \sin \alpha \cos \theta + \cos \alpha \sin \theta
# \end{bmatrix}
# $$
#
# 4. Karena $x = r \cos \alpha$ dan $y = r \sin \alpha$, maka:
#
# $$
# \mathbf{v'} =
# \begin{bmatrix}
# \cos \theta & -\sin \theta \\
# \sin \theta & \cos \theta
# \end{bmatrix}
# \begin{bmatrix}
# x \\
# y
# \end{bmatrix}
# $$
#
# Artinya, rotasi memang dapat direpresentasikan oleh matriks di atas.
